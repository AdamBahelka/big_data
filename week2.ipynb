# %%
import numpy as np
import math
import time
L1M = []
A1M= np.random.randint(-5, 5, size= 1000000)
np.sum(np.sin(A1M))
# Out:
# 96362.41345498171

# %%
tweets = np.random.randint(11,size= (5, 1000000)) 
print ( tweets.shape)
s =np.sum(tweets, axis=0)
s = s/5
s.shape
a = np.argmax(s)
b = np.max(s)
print (a, b)
# Out:
# (5, 1000000)
# 50161 10.0

# %%
import os
import json
import time
import random
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
# Load a pokemon image and inspect it
path = "C:\\Users\\abahe\\OneDrive\\Documents\\Pythonprogramming\\Pokemon_dataset\\Abra\\2eb2a528f9a247358452b3c740df69a0.jpg"
pokemon = Image.open(path)
path = "C:\\Users\\abahe\\OneDrive\\Documents\\Pythonprogramming\\Pokemon_dataset\\Abra\\10a9f06ec6524c66b779ea80354f8519.jpg"
pokemon2 = Image.open(path)

print(pokemon.size)
pokemon
# Out:
# (278, 238)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=278x238>

# %%
background = Image.new(pokemon2.mode, (500, 500),(255, 255, 255))
